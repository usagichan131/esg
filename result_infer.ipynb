# %%
import pandas as pd

# %%
deci_macd = pd.read_excel('decimalodd_res/macd.xlsx', index_col=0)
deci_macd
# Out:
#      Company  Final Portfolio Value  Total Profit  Rate of Return
# 0        CCU           80133.211133 -19866.788867      -19.866789
# 1        CNH           52961.894661 -47038.105339      -47.038105
# 2   TIETO.HE          109180.749034   9180.749034        9.180749
# 3    BAYN.BE          142394.515892  42394.515892       42.394516
# 4   SGSNZ.XC          109240.974747   9240.974747        9.240975
# 5        VOC           52718.345528 -47281.654472      -47.281654
# 6       VRSK          112489.472828  12489.472828       12.489473
# 7     19MA.F          193867.584953  93867.584953       93.867585
# 8    QNBK.QA          114176.023527  14176.023527       14.176024
# 9    1605.TW           74844.570094 -25155.429906      -25.155430
# 10       GME          134761.135498  34761.135498       34.761135
# 11      FOSL           47958.584461 -52041.415539      -52.041416
# 12        GT          136205.127892  36205.127892       36.205128
# 13       HOG           65303.004616 -34696.995384      -34.696995
# 14      PDCO           95163.154905  -4836.845095       -4.836845

# %%
deci_macd_profit = deci_macd['Rate of Return'][deci_macd['Rate of Return'] > 0].sum()/len(deci_macd)
deci_macd_loss = deci_macd['Rate of Return'][deci_macd['Rate of Return'] < 0].sum()/len(deci_macd)

# %%
print(deci_macd_profit, deci_macd_loss)
# Out:
# 16.821038958052792 -15.394482306746644

# %%
deci_bb = pd.read_excel('decimalodd_res/bb.xlsx', index_col=0)
deci_bb_profit = deci_bb['Rate of Return'][deci_bb['Rate of Return'] > 0].sum()/len(deci_bb)
deci_bb_loss = deci_bb['Rate of Return'][deci_bb['Rate of Return'] < 0].sum()/len(deci_bb)
print(deci_bb_profit, deci_bb_loss)
# Out:
# 17.184445748381318 -12.646845040373007

# %%
deci_obv = pd.read_excel('decimalodd_res/obv.xlsx', index_col=0)
deci_obv_profit = deci_obv['Rate of Return'][deci_obv['Rate of Return'] > 0].sum()/len(deci_obv)
deci_obv_loss = deci_obv['Rate of Return'][deci_obv['Rate of Return'] < 0].sum()/len(deci_obv)
print(deci_obv_profit, deci_obv_loss)
# Out:
# 6.811423450533549 -14.840651246456305

# %%
wr_macd = pd.read_excel('winrate_result/macd.xlsx', index_col=0)
wr_macd
# Out:
#           CCU   TIETO.HE    BAYN.BE   SGSNZ.XC  VOC       VRSK     19MA.F  \
# 5   50.000000  65.217391  70.588235  41.176471   50  47.058824  61.538462
# 10  47.826087  63.636364  58.823529  47.058824   50  64.705882  53.846154
# 15  43.478261  59.090909  52.941176  41.176471   30  70.588235  46.153846
# 20  65.217391  63.636364  52.941176  52.941176   30  47.058824  53.846154
# 25  47.826087  68.181818  58.823529  43.750000   30  70.588235  61.538462
# 30  43.478261  71.428571  62.500000  37.500000   50  70.588235  69.230769
#
#       QNBK.QA    1605.TW        GME       FOSL         GT        HOG  \
# 5   37.500000  52.173913  60.000000  41.176471  66.666667  47.619048
# 10  43.750000  47.826087  60.000000  23.529412  66.666667  45.000000
# 15  46.666667  54.545455  66.666667  29.411765  60.000000  55.000000
# 20  42.857143  57.142857  60.000000  11.764706  60.000000  35.000000
# 25  50.000000  47.619048  53.333333  18.750000  46.666667  35.000000
# 30  42.857143  47.619048  60.000000   6.250000  50.000000  30.000000
#
#          PDCO        CNH
# 5   39.130435  39.130435
# 10  40.909091  47.826087
# 15  27.272727  26.086957
# 20  50.000000  47.826087
# 25  50.000000  47.826087
# 30  57.142857  40.909091

# %%
zero_macd = wr_macd.columns[(wr_macd == 0).all()]
wr_macd['macd_average'] = wr_macd.drop(columns=zero_macd).mean(axis=1)
wr_macd
# Out:
#           CCU   TIETO.HE    BAYN.BE   SGSNZ.XC  VOC       VRSK     19MA.F  \
# 5   50.000000  65.217391  70.588235  41.176471   50  47.058824  61.538462
# 10  47.826087  63.636364  58.823529  47.058824   50  64.705882  53.846154
# 15  43.478261  59.090909  52.941176  41.176471   30  70.588235  46.153846
# 20  65.217391  63.636364  52.941176  52.941176   30  47.058824  53.846154
# 25  47.826087  68.181818  58.823529  43.750000   30  70.588235  61.538462
# 30  43.478261  71.428571  62.500000  37.500000   50  70.588235  69.230769
#
#       QNBK.QA    1605.TW        GME       FOSL         GT        HOG  \
# 5   37.500000  52.173913  60.000000  41.176471  66.666667  47.619048
# 10  43.750000  47.826087  60.000000  23.529412  66.666667  45.000000
# 15  46.666667  54.545455  66.666667  29.411765  60.000000  55.000000
# 20  42.857143  57.142857  60.000000  11.764706  60.000000  35.000000
# 25  50.000000  47.619048  53.333333  18.750000  46.666667  35.000000
# 30  42.857143  47.619048  60.000000   6.250000  50.000000  30.000000
#
#          PDCO        CNH  macd_average
# 5   39.130435  39.130435     51.265090
# 10  40.909091  47.826087     50.760279
# 15  27.272727  26.086957     47.271942
# 20  50.000000  47.826087     48.682125
# 25  50.000000  47.826087     48.660218
# 30  57.142857  40.909091     49.300265

# %%
wr_bb = pd.read_excel('winrate_result/bb.xlsx', index_col=0)
zero_bb = wr_bb.columns[(wr_bb == 0).all()]
wr_bb['bb_average'] = wr_bb.drop(columns=zero_bb).mean(axis=1)
wr_bb
# Out:
#            CCU        CNH  TIETO.HE     BAYN.BE   SGSNZ.XC        VOC  VRSK  \
# 5    71.428571  41.666667        80  100.000000  63.636364  23.529412    50
# 10   71.428571  41.666667        60  100.000000  63.636364  17.647059    75
# 15   66.666667  41.666667        80  100.000000  81.818182  17.647059    75
# 20   66.666667  25.000000        80   66.666667  81.818182  26.666667    75
# 25   83.333333  25.000000        80   66.666667  72.727273  20.000000   100
# 30  100.000000  33.333333       100   66.666667  72.727273  20.000000   100
#
#        19MA.F    QNBK.QA    1605.TW  GME       FOSL          GT   HOG  PDCO  \
# 5   50.000000  75.000000  63.636364   75  91.666667   66.666667  62.5   100
# 10  58.333333  66.666667  81.818182   25  75.000000   66.666667  75.0   100
# 15  58.333333  83.333333  81.818182   25  58.333333   83.333333  87.5   100
# 20  58.333333  75.000000  54.545455   25  50.000000  100.000000  87.5   100
# 25  75.000000  81.818182  63.636364   25  41.666667  100.000000  87.5   100
# 30  50.000000  72.727273  63.636364   25  33.333333   83.333333  50.0   100
#
#     bb_average
# 5    67.648714
# 10   65.190901
# 15   69.363339
# 20   64.813131
# 25   68.156566
# 30   64.717172

# %%
wr_obv = pd.read_excel('winrate_result/obv.xlsx', index_col=0)
zero_obv = wr_obv.columns[(wr_obv == 0).all()]
wr_obv['obv_average'] = wr_obv.drop(columns=zero_obv).mean(axis=1)
wr_obv
# Out:
#           CCU        CNH    TIETO.HE  BAYN.BE    SGSNZ.XC        VOC  VRSK  \
# 5   33.333333  16.666667   66.666667       50   33.333333  25.000000    40
# 10  33.333333  16.666667   66.666667       50   66.666667   0.000000    60
# 15  33.333333  33.333333  100.000000       50  100.000000  33.333333    80
# 20  33.333333  16.666667  100.000000       50  100.000000  33.333333   100
# 25  66.666667  33.333333  100.000000        0  100.000000  33.333333    80
# 30  66.666667  33.333333  100.000000       50  100.000000  66.666667    80
#
#     19MA.F  QNBK.QA  1605.TW  GME       FOSL   GT  HOG  PDCO  obv_average
# 5        0      100       50   80  25.000000  100  100     0    51.428571
# 10       0      100        0   80  25.000000  100  100     0    49.880952
# 15       0      100        0   80  25.000000  100  100     0    59.642857
# 20       0      100        0   80  25.000000  100  100     0    59.880952
# 25       0      100        0  100  25.000000   50  100     0    56.309524
# 30       0      100        0   80  33.333333   50  100   100    68.571429
