# %%
from utils.portfolio import portfolio_buy_sell, portfolio_only_buy
from utils.calculations import kelly_criterion
from utils.config import *
import pandas as pd

# %%
ESG = ['CTD', 'DPM', 'FPT', 'GAS', 'MBB', 'NVL', 'PNJ', 'REE', 'SBT', 'SSI', 'STB', 'VIC', 'VNM']
non_ESG = ['BID', 'BVH', 'CTG', 'EIB', 'GMD', 'HDB', 'HPG', 'MSN', 'MWG', 'ROS', 'SAB', 'TCB', 'VCB', 'VHM', 'VJC', 'VRE', 'VPB']

# %%
rf = {'2019': 0.0451, '2020': 0.0286, '2021': 0.023, '2022': 0.0335, '2023': 0.0321}
rf = pd.Series(rf)
rf_cal = rf.mean()
rf_2022 = 0.0335

# %%
f_macd = kelly_criterion(signal='macd')
f_bb = kelly_criterion(signal='bb')
f_obv = kelly_criterion(signal='obv')
print(f_macd, f_bb, f_obv)
# Out:
# 0.31117849987166046 0.3513615215852551 0.1071147948050976

# %%
esg, describe, metrics_macd_non = portfolio_buy_sell(
        non_ESG, 
        start_date='2022-01-01',
        end_date='2022-12-18',
        f_star=1,
        rf=rf_2022,
        signal='macd'
    )
esg, describe, metrics_bb_non = portfolio_buy_sell(
        non_ESG, 
        start_date='2022-01-01',
        end_date='2022-12-18',
        f_star=1,
        rf=rf_2022,
        signal='bb'
    )
esg, describe, metrics_obv_non = portfolio_buy_sell(
        non_ESG, 
        start_date='2022-01-01',
        end_date='2022-12-18',
        f_star=1,
        rf=rf_2022,
        signal='obv'
    )
# Out:
# 2025-01-14 23:31:05 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:31:07 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:31:09 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:31:11 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:31:12 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:31:14 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:31:16 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# ...

# %%
merged_non_22 = pd.concat([metrics_macd_non, metrics_bb_non, metrics_obv_non])
merged_non_22['ESG'] = 'No'
merged_non_22['period'] = '2022-2023'
merged_non_22
# Out:
#    Sharpe Ratio  Sortino Ratio       VaR        RoR       MDD  Skewness  \
# 0     -0.173962      -0.090881 -0.021336  -2.160443 -0.139114  1.785666
# 0      0.081676       0.097759 -0.059856  -7.776783 -0.266184  0.709408
# 0      0.172030       0.222620 -0.088806 -14.784873 -0.410120  4.166474
#
#     Kurtosis  Buying Trades  Selling Trades Kelly ESG     period
# 0  26.220564            122             108    No  No  2022-2023
# 0  12.797147             22              11    No  No  2022-2023
# 0  78.136739             23               4    No  No  2022-2023

# %%
esg, describe, metrics_macd_non = portfolio_buy_sell(
        ESG, 
        start_date='2022-01-01',
        end_date='2022-12-18',
        f_star=1,
        rf=rf_2022,
        signal='macd'
    )
esg, describe, metrics_bb_non = portfolio_buy_sell(
        ESG, 
        start_date='2022-01-01',
        end_date='2022-12-18',
        f_star=1,
        rf=rf_2022,
        signal='bb'
    )
esg, describe, metrics_obv_non = portfolio_buy_sell(
        ESG, 
        start_date='2022-01-01',
        end_date='2022-12-18',
        f_star=1,
        rf=rf_2022,
        signal='obv'
    )
# Out:
# 2025-01-14 23:32:40 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:32:42 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:32:43 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:32:45 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:32:46 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:32:48 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:32:50 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# ...

# %%
merged_ESG_22 = pd.concat([metrics_macd_non, metrics_bb_non, metrics_obv_non])
merged_ESG_22['ESG'] = 'Yes'
merged_ESG_22['period'] = '2022-2023'
merged_ESG_22
# Out:
#    Sharpe Ratio  Sortino Ratio       VaR       RoR       MDD   Skewness  \
# 0      0.232406       0.162842 -0.010663   5.10402 -0.046514  12.565230
# 0     -0.045593      -0.056456 -0.052114 -10.18707 -0.325094   1.001254
# 0      0.122888       0.136594 -0.071569 -11.79222 -0.383509   0.250943
#
#      Kurtosis  Buying Trades  Selling Trades Kelly  ESG     period
# 0  184.692241             99              87    No  Yes  2022-2023
# 0   10.835486             22              11    No  Yes  2022-2023
# 0   48.231222             14               4    No  Yes  2022-2023

# %%
esg, describe, metrics_macd_non = portfolio_buy_sell(
        ESG, 
        start_date='2022-01-01',
        end_date='2022-12-18',
        f_star=f_macd,
        rf=rf_2022,
        signal='macd'
    )
esg, describe, metrics_bb_non = portfolio_buy_sell(
        ESG, 
        start_date='2022-01-01',
        end_date='2022-12-18',
        f_star=f_bb,
        rf=rf_2022,
        signal='bb'
    )
esg, describe, metrics_obv_non = portfolio_buy_sell(
        ESG, 
        start_date='2022-01-01',
        end_date='2022-12-18',
        f_star=f_obv,
        rf=rf_2022,
        signal='obv'
    )
# Out:
# 2025-01-14 23:33:59 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:34:01 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:34:03 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:34:04 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:34:06 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:34:07 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:34:09 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# ...

# %%
merged_ESG_22_kelly = pd.concat([metrics_macd_non, metrics_bb_non, metrics_obv_non])
merged_ESG_22_kelly['ESG'] = 'Yes'
merged_ESG_22_kelly['period'] = '2022-2023'
merged_ESG_22_kelly
# Out:
#    Sharpe Ratio  Sortino Ratio       VaR      RoR       MDD  Skewness  \
# 0     -0.100192      -0.065854 -0.010746  1.69275 -0.076260  8.968265
# 0     -0.223844      -0.273470 -0.032271 -7.58903 -0.223171  0.501211
# 0     -0.421334      -0.473765 -0.009673 -0.94629 -0.052769 -0.318105
#
#      Kurtosis  Buying Trades  Selling Trades Kelly  ESG     period
# 0  134.884378            921             129   Yes  Yes  2022-2023
# 0    6.549452            105              11   Yes  Yes  2022-2023
# 0   16.092495             32               4   Yes  Yes  2022-2023

# %%
esg, describe, metrics_macd_non = portfolio_buy_sell(
        non_ESG, 
        start_date='2022-01-01',
        end_date='2022-12-18',
        f_star=f_macd,
        rf=rf_2022,
        signal='macd'
    )
esg, describe, metrics_bb_non = portfolio_buy_sell(
        non_ESG, 
        start_date='2022-01-01',
        end_date='2022-12-18',
        f_star=f_bb,
        rf=rf_2022,
        signal='bb'
    )
esg, describe, metrics_obv_non = portfolio_buy_sell(
        non_ESG, 
        start_date='2022-01-01',
        end_date='2022-12-18',
        f_star=f_obv,
        rf=rf_2022,
        signal='obv'
    )
# Out:
# 2025-01-14 23:35:07 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:35:09 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:35:10 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 23:35:12 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# Error occurred for EIB: Out of bounds nanosecond timestamp: 9223545600000000000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 esg, describe, metrics_macd_non = portfolio_buy_sell(
#       2         non_ESG,
#       3         start_date='2022-01-01',
#       4         end_date='2022-12-18',
#       5         f_star=f_macd,
# ...

# %%
merged_non_22_kelly = pd.concat([metrics_macd_non, metrics_bb_non, metrics_obv_non])
merged_non_22_kelly['ESG'] = 'No'
merged_non_22_kelly['period'] = '2022-2023'
merged_non_22_kelly
# Out:
#    Sharpe Ratio  Sortino Ratio       VaR        RoR       MDD  Skewness  \
# 0     -1.813617      -0.808652 -0.016921 -23.185903 -0.231859 -1.113339
# 0     -0.401326      -0.449622 -0.024644  -8.693063 -0.223328 -0.524356
# 0     -0.544881      -0.540252 -0.016326  -6.287113 -0.111252 -0.680827
#
#     Kurtosis  Buying Trades  Selling Trades Kelly ESG     period
# 0  29.473284            231               0   Yes  No  2022-2023
# 0   6.078144            106               0   Yes  No  2022-2023
# 0  27.767222             40               0   Yes  No  2022-2023

# %%
esg, describe, metrics_macd_non = portfolio_buy_sell(
        ESG, 
        start_date='2019-01-01',
        end_date='2024-01-04',
        f_star=1,
        rf=rf_cal,
        signal='macd'
    )
esg, describe, metrics_bb_non = portfolio_buy_sell(
        ESG, 
        start_date='2019-01-01',
        end_date='2024-01-04',
        f_star=1,
        rf=rf_cal,
        signal='bb'
    )
esg, describe, metrics_obv_non = portfolio_buy_sell(
        ESG, 
        start_date='2019-01-01',
        end_date='2024-01-04',
        f_star=1,
        rf=rf_cal,
        signal='obv'
    )
# Out:
# 2025-01-14 22:07:37 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:07:39 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:07:41 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:07:43 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:07:45 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:07:47 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:07:48 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# ...

# %%
merged_ESG_24 = pd.concat([metrics_macd_non, metrics_bb_non, metrics_obv_non])
merged_ESG_24['ESG'] = 'Yes'
merged_ESG_24['period'] = '2019-2024'
merged_ESG_24
# Out:
#    Sharpe Ratio  Sortino Ratio       VaR        RoR       MDD   Skewness  \
# 0      0.653491       0.454841 -0.015095   81.87896 -0.207869  13.466116
# 0      0.457682       0.524039 -0.025891   78.67600 -0.384343   0.428884
# 0      0.418445       0.733707 -0.082166  102.79312 -0.614242  23.447963
#
#      Kurtosis  Buying Trades  Selling Trades Kelly  ESG     period
# 0  309.669632             16               0    No  Yes  2019-2024
# 0   27.869696             15               0    No  Yes  2019-2024
# 0  797.002381             17               0    No  Yes  2019-2024

# %%
esg, describe, metrics_macd_non = portfolio_buy_sell(
        non_ESG, 
        start_date='2019-01-01',
        end_date='2024-01-04',
        f_star=1,
        rf=rf_cal,
        signal='macd'
    )
esg, describe, metrics_bb_non = portfolio_buy_sell(
        non_ESG, 
        start_date='2019-01-01',
        end_date='2024-01-04',
        f_star=1,
        rf=rf_cal,
        signal='bb'
    )
esg, describe, metrics_obv_non = portfolio_buy_sell(
        non_ESG, 
        start_date='2019-01-01',
        end_date='2024-01-04',
        f_star=1,
        rf=rf_cal,
        signal='obv'
    )
# Out:
# 2025-01-14 22:09:02 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:09:04 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:09:06 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:09:09 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:09:11 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:09:14 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:09:16 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# ...

# %%
merged_non_24 = pd.concat([metrics_macd_non, metrics_bb_non, metrics_obv_non])
merged_non_24['ESG'] = 'No'
merged_non_24['period'] = '2019-2024'
merged_non_24
# Out:
#    Sharpe Ratio  Sortino Ratio       VaR        RoR       MDD   Skewness  \
# 0      0.386598       0.213968 -0.012648  44.131527 -0.146962  15.923055
# 0      0.356720       0.413827 -0.023861  55.279097 -0.392010  -0.174410
# 0      0.371475       0.838479 -0.116643  57.907267 -0.704430  28.663582
#
#      Kurtosis  Buying Trades  Selling Trades Kelly ESG     period
# 0  416.944931             25               0    No  No  2019-2024
# 0   11.938581             20               0    No  No  2019-2024
# 0  983.535845             24               0    No  No  2019-2024

# %%
esg, describe, metrics_macd_non = portfolio_buy_sell(
        ESG, 
        start_date='2019-01-01',
        end_date='2024-01-04',
        f_star=f_macd,
        rf=rf_cal,
        signal='macd'
    )
esg, describe, metrics_bb_non = portfolio_buy_sell(
        ESG, 
        start_date='2019-01-01',
        end_date='2024-01-04',
        f_star=f_bb,
        rf=rf_cal,
        signal='bb'
    )
esg, describe, metrics_obv_non = portfolio_buy_sell(
        ESG, 
        start_date='2019-01-01',
        end_date='2024-01-04',
        f_star=f_obv,
        rf=rf_cal,
        signal='obv'
    )
# Out:
# 2025-01-14 22:10:49 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:10:54 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:10:56 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:10:58 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:11:00 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:11:03 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:11:05 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# ...

# %%
merged_ESG_24_kelly = pd.concat([metrics_macd_non, metrics_bb_non, metrics_obv_non])
merged_ESG_24_kelly['ESG'] = 'Yes'
merged_ESG_24_kelly['period'] = '2019-2024'
merged_ESG_24_kelly
# Out:
#    Sharpe Ratio  Sortino Ratio       VaR       RoR       MDD   Skewness  \
# 0      0.660328       0.462856 -0.014993  82.35292 -0.206416  13.497061
# 0      0.524753       0.617485 -0.020284  79.40002 -0.389425  -0.606197
# 0      0.206235       0.232745 -0.010515  27.21099 -0.244895  -0.388282
#
#      Kurtosis  Buying Trades  Selling Trades Kelly  ESG     period
# 0  311.317047            203               0   Yes  Yes  2019-2024
# 0    2.954992            164               0   Yes  Yes  2019-2024
# 0   20.474091             69               0   Yes  Yes  2019-2024

# %%
esg, describe, metrics_macd_non = portfolio_buy_sell(
        non_ESG, 
        start_date='2019-01-01',
        end_date='2024-01-04',
        f_star=f_macd,
        rf=rf_cal,
        signal='macd'
    )
esg, describe, metrics_bb_non = portfolio_buy_sell(
        non_ESG, 
        start_date='2019-01-01',
        end_date='2024-01-04',
        f_star=f_bb,
        rf=rf_cal,
        signal='bb'
    )
esg, describe, metrics_obv_non = portfolio_buy_sell(
        non_ESG, 
        start_date='2019-01-01',
        end_date='2024-01-04',
        f_star=f_obv,
        rf=rf_cal,
        signal='obv'
    )
# Out:
# 2025-01-14 22:12:02 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:12:04 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:12:06 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:12:08 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:12:09 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:12:11 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2025-01-14 22:12:13 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# ...

# %%
merged_non_24_kelly = pd.concat([metrics_macd_non, metrics_bb_non, metrics_obv_non])
merged_non_24_kelly['ESG'] = 'No'
merged_non_24_kelly['period'] = '2019-2024'
merged_non_24_kelly
# Out:
#    Sharpe Ratio  Sortino Ratio       VaR        RoR       MDD   Skewness  \
# 0      0.400299       0.225560 -0.012636  45.360687 -0.142686  16.138113
# 0      0.377934       0.440240 -0.020038  54.425247 -0.385803  -0.809140
# 0      0.073779       0.081012 -0.011216  18.710867 -0.228336  -0.308752
#
#      Kurtosis  Buying Trades  Selling Trades Kelly ESG     period
# 0  424.422293            252               0   Yes  No  2019-2024
# 0    4.465503            206               0   Yes  No  2019-2024
# 0   28.942253            108               0   Yes  No  2019-2024

# %%
merged_non_24_kelly
# Out:
#    Sharpe Ratio  Sortino Ratio       VaR        RoR       MDD   Skewness  \
# 0      0.400299       0.225560 -0.012636  45.360687 -0.142686  16.138113
# 0      0.377934       0.440240 -0.020038  54.425247 -0.385803  -0.809140
# 0      0.073779       0.081012 -0.011216  18.710867 -0.228336  -0.308752
#
#      Kurtosis  Buying Trades  Selling Trades Kelly ESG     period
# 0  424.422293            252               0   Yes  No  2019-2024
# 0    4.465503            206               0   Yes  No  2019-2024
# 0   28.942253            108               0   Yes  No  2019-2024

# %%
merged_all = pd.concat([merged_non_22, merged_ESG_22, merged_non_22_kelly, merged_ESG_22_kelly, \
                        merged_non_24, merged_ESG_24, merged_non_24_kelly, merged_ESG_24_kelly])

# %%
merged_all
# Out:
#    Sharpe Ratio  Sortino Ratio       VaR         RoR       MDD   Skewness  \
# 0     -1.837149      -0.819839 -0.017008  -23.573113 -0.235731  -1.151436
# 0     -0.210159      -0.237490 -0.040589  -11.978373 -0.320433  -0.108218
# 0      0.085488       0.107717 -0.082189  -18.232903 -0.410120   4.860313
# 0     -2.598438      -0.878784 -0.012911  -24.224360 -0.242244  -7.978986
# 0     -0.634640      -0.773803 -0.032343  -19.105420 -0.296900   0.780686
# 0      0.018164       0.019922 -0.066467  -16.070230 -0.383509   0.286942
# 0     -1.813617      -0.808652 -0.016921  -23.185903 -0.231859  -1.113339
# 0     -0.401326      -0.449622 -0.024644   -8.693063 -0.223328  -0.524356
# 0     -0.544881      -0.540252 -0.016326   -6.287113 -0.111252  -0.680827
# 0     -2.634563      -0.894105 -0.012835  -24.371260 -0.243713  -7.785125
# 0     -0.951092      -1.190821 -0.019392  -14.756340 -0.266151   0.037110
# 0     -0.590088      -0.691537 -0.008760   -1.980510 -0.072390  -0.289248
# ...

# %%
merged_all.to_excel('sell_buy.xlsx')
